# %% [markdown]
# # Implementation of the Q-learning algorithm on the taxi scheduling env

# %%
import random
import gym

# %% [markdown]
# ## <a id="td0"></a>Reminder: Temporal Differences learning
#
# We want to replace Monte-Carlo estimation by a step by step update that only takes $(s,r,s')$ as an input. The key remark we make is that once the $(s,r,s')$ transition is over we can update our knowledge of $V(s)$ by using $r+\gamma V(s')$. This estimate uses $V(s')$ to *bootstrap*[1] the estimator of $V(s)$.
#
#
# To get an intuitive understanding of why we can do that, take the following example. You are driving from home to the airport. Half-way, you realize traffic is denser than you usually estimate and you're already 5 minutes behind schedule. Home is $s$, half-way is $s'$, those 5 minutes are $r$. To update your belief about the average length of the trip home$\rightarrow$airport ($V(s)$), you don't need to wait until you reach the airport (as a Monte-Carlo estimate would have required). Instead, you can update this belief using $r+V(s')$, the sum of what you observed and what you currently estimate for the rest of the trip. As long as you update all states often enough, the whole procedure should converge to the true $V$.
#
# So here is the update that we shall call TD(0):
# <div class="alert-success">**TD(0) temporal difference update:**
# $$V(s) \leftarrow V(s) + \alpha \left[ r + \gamma V(s') - V(s) \right]$$
# </div>
#
# $\delta=r + \gamma V(s') - V(s)$ is called the prediction **temporal difference** . It is the difference between our estimate $V(s)$ *before* obtaining the information of $r$ and the bootstrapped value $r+\gamma V(s')$.
# <div class="alert-success">**Temporal difference:**
# $$\delta=r + \gamma V(s') - V(s)$$
# </div>
#
# **Bootstrapping** is the operation of using the value of $V(s')$ to update $V(s)$.
#
# This is a sample-by-sample update (no need to remember full episodes) and, more importantly, it is adapted to non-episodic environments (with no terminal states). As for online Monte-Carlo, the update above converges to $V^\pi$ if $\alpha$ respects the Robbins-Monro conditions:
# $$\sum\limits_{t=0}^\infty \alpha_t = \infty \quad \textrm{  and  } \quad \sum\limits_{t=0}^\infty \alpha_t^2 < \infty.$$
#
# Often, TD methods converge faster and are more robust estimators than Monte Carlo ones (but not always).

# %% [markdown]
# <div class="alert-success">**TD(0) temporal difference update on $Q$-functions:**<br>
# In practice, we use TD update on $Q$ functions for the control problem (finding the optimal policy)
# For a sample $(s,a,r,s')$, the temporal difference can take two forms:
#
# * 1. SARSA (on-policy algorithm): $$\delta = r + \gamma Q(s',\pi(s')) - Q(s,a)$$
# And the TD update is:
# $$Q(s,a) \leftarrow Q(s,a) + \alpha \left[ r + \gamma Q(s'\pi(s')) - Q(s,a) \right]$$
#
# * 2. **Q-learning (off-policy algorithm), the focus of this notebook**: $$\delta = r + \gamma \max \limits_{a' \in A} Q(s',a') - Q(s,a)$$
# And the TD update is:
# $$Q(s,a) \leftarrow Q(s,a) + \alpha \left[r + \gamma \max \limits_{a' \in A} Q(s',a') - Q(s,a) \right]$$
#
# In both cases, as long as all state-action pairs $(s,a)$ are sampled infinitely often as $t\rightarrow\infty$, and under the Robbins-Monro conditions, this procedure converges to $Q^\pi$.
# </div>

# %% [markdown]
# ![Q-learning-algo.png](attachment:Q-learning-algo.png)

# %% [markdown]
# ### Looking at the environment

# %%
env=gym.make('Taxi-v1')
# Out:
# [2019-08-29 20:22:54,496] Making new env: Taxi-v1

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %% [markdown]
#     Rendering:
#     - blue: passenger
#     - magenta: destination
#     - yellow: empty taxi
#     - green: full taxi
#     - other letters (R, G, B and Y): locations for passengers and destinations

# %%
env.observation_space.n
# Out:
# 500

# %%
env.action_space.n
# Out:
# 6

# %% [markdown]
#   actions:
#     - 0: south
#     - 1: north
#     - 2: east
#     - 3: west
#     - 4: pickup
#     - 5: dropoff

# %% [markdown]
# **rewards**:
# * +20 for passenger dropped at the right location
# * -10 for drop-off at the wrong location
# * -10 for pick-up in a cell with no passenger
# * -1 for every other action

# %% [markdown]
# **The key to generate episodes is the 'env.step(action)' in openAI gym**

# %%
state=env.reset()
for action in range(env.action_space.n):
    next_state, reward, done, _=env.step(action)
    # done is a boolean assessing if the next state is a terminal one

# %% [markdown]
# ### Parameters of the algorithm

# %%
alpha=0.8 # parameter in the TD-update
gamma=0.9 # discount rate

# parameters for building a epsilon-greedy policy with decay
epsilon=0.2
decay_steps=500
decay_rate=0.01

# number of iterations for applying the algorithm
n_iterations=50000 

# to compute the moving average of the reward 
moving_period=100

# %% [markdown]
# ### Defining a epsilon-greedy policy

# %%
def epsilon_greedy(state, epsilon):
    if random.uniform(0,1)<epsilon:
        return env.action_space.sample()
    else:
        return max(list(range(env.action_space.n)), key=lambda x:q [(state,x)])

# %%
# function to update the q value function in function of a transition - computation of the TD update
def update_q_table(state, action, reward, next_state, alpha, gamma):
    qa=max(q[next_state,a] for a in range(env.action_space.n))
    q[(state,action)]+=alpha*(reward+gamma*qa-q[(prev_state,action)])

# %% [markdown]
# ### Steps to implement the Q-learning algorithm

# %% [markdown]
# * Initialize the Q value function (= q table), and a cumulative reward equal to 0
# * Loop over the iterations
# * Generate an episode by initializing the state s
# * Take the first action a with a epsilon-greedy policy
# * Perform a step in the environment with the 'env.step' function, and store the next state, the reward and the boolean 'done'
# * Update the q value for the pair (s,a): $$Q(s,a) \leftarrow Q(s,a) + \alpha \left[r + \gamma \max \limits_{a' \in A} Q(s',a') - Q(s,a) \right]$$
# * assign the current state to the next state
# * update the cumulative rewards by adding the reward of the transition
# * Check if the next state is a terminal state: if so break the loop over the episodes

# %% [markdown]
# ### Implementing the Q-learning algorithm

# %%
#initializing the Q_table
q={}
for s in range(env.observation_space.n):
    for a in range(env.action_space.n):
        q[(s,a)]=0.0
reward_episodes=[]
reward_MA=[]
        
for i in range(n_iterations):
    r=0
    prev_state=env.reset()
    while True:
        #env.render()
        
        # decaying the epsilon every decay8steps
        if i % decay_steps==0:
            epsilon=max(0,epsilon-decay_rate)
        # In each state, we perform the action according to the epsilon greedy policy
        action=epsilon_greedy(prev_state, epsilon)
        
        # Then we perform the transition to the next time step
        next_state, reward, done, _=env.step(action)
        
        # update of the Q_value using the updated_q_function
        # with the Q_learning rule
        update_q_table(prev_state, action, reward, next_state, alpha, gamma)
        
        # Finally we update the previous state as next state
        prev_state=next_state
        
        #store all the rewards obtained
        r+=reward
        
        # breaking hte loop if reaching the terminal state
        if done:
            break
    
        
    #print("total reward:{}".format(r))
    reward_episodes.append(r)
    
    if i % moving_period==0 and i!=0:
        reward_moving_average=sum(reward_episodes[i-moving_period:i])/moving_period
        print('reward MA', reward_moving_average)
        reward_MA.append(reward_moving_average)
    
env.close()
# Out:
# reward MA -208.86
# reward MA 1.07
# reward MA 5.41
# reward MA 8.47
# reward MA 9.93
# reward MA 9.52
# reward MA 9.9
# reward MA 9.07
# reward MA 9.4
# reward MA 9.74
# reward MA 8.94
# reward MA 10.68
# reward MA 9.8
# reward MA 10.09
# reward MA 9.78
# reward MA 9.23
# reward MA 9.78
# reward MA 9.69
# reward MA 9.97
# reward MA 9.6
# reward MA 9.2
# reward MA 9.31
# reward MA 10.27
# reward MA 9.55
# reward MA 10.1
# reward MA 10.06
# reward MA 9.1
# reward MA 9.68
# reward MA 10.07
# reward MA 10.33
# reward MA 9.77
# reward MA 9.94
# reward MA 9.46
# reward MA 9.72
# reward MA 9.98
# reward MA 9.93
# reward MA 9.77
# reward MA 9.5
# reward MA 9.66
# reward MA 10.26
# reward MA 9.58
# reward MA 10.03
# reward MA 9.55
# reward MA 9.85
# reward MA 10.09
# reward MA 10.02
# reward MA 9.78
# reward MA 9.23
# reward MA 9.46
# reward MA 9.48
# reward MA 9.67
# reward MA 10.43
# reward MA 9.83
# reward MA 9.85
# reward MA 9.39
# reward MA 9.29
# reward MA 9.78
# reward MA 9.66
# reward MA 9.85
# reward MA 9.64
# reward MA 9.79
# reward MA 10.27
# reward MA 9.74
# reward MA 10.06
# reward MA 9.63
# reward MA 9.36
# reward MA 9.19
# reward MA 10.21
# reward MA 9.92
# reward MA 9.99
# reward MA 9.41
# reward MA 9.37
# reward MA 9.63
# reward MA 9.27
# reward MA 9.96
# reward MA 10.03
# reward MA 9.07
# reward MA 9.63
# reward MA 10.33
# reward MA 10.08
# reward MA 9.22
# reward MA 9.83
# reward MA 9.35
# reward MA 10.01
# reward MA 10.2
# reward MA 9.85
# reward MA 10.02
# reward MA 9.42
# reward MA 9.58
# reward MA 10.07
# reward MA 9.6
# reward MA 10.03
# reward MA 10.21
# reward MA 9.92
# reward MA 9.52
# reward MA 10.48
# reward MA 9.99
# reward MA 9.98
# reward MA 9.75
# reward MA 9.74
# reward MA 9.87
# reward MA 9.82
# reward MA 9.88
# reward MA 9.78
# reward MA 9.98
# reward MA 9.63
# reward MA 9.46
# reward MA 9.73
# reward MA 10.03
# reward MA 10.23
# reward MA 10.21
# reward MA 10.15
# reward MA 10.24
# reward MA 9.73
# reward MA 9.53
# reward MA 10.74
# reward MA 9.84
# reward MA 9.97
# reward MA 9.6
# reward MA 9.88
# reward MA 10.39
# reward MA 10.25
# reward MA 9.59
# reward MA 9.84
# reward MA 10.25
# reward MA 10.21
# reward MA 9.28
# reward MA 9.64
# reward MA 9.57
# reward MA 9.59
# reward MA 10.13
# reward MA 10.02
# reward MA 9.22
# reward MA 9.67
# reward MA 10.05
# reward MA 9.72
# reward MA 9.94
# reward MA 10.22
# reward MA 9.4
# reward MA 9.18
# reward MA 9.99
# reward MA 10.57
# reward MA 10.15
# reward MA 9.39
# reward MA 10.22
# reward MA 10.35
# reward MA 9.38
# reward MA 9.57
# reward MA 9.78
# reward MA 10.6
# reward MA 10.26
# reward MA 9.69
# reward MA 10.27
# reward MA 10.03
# reward MA 9.71
# reward MA 9.45
# reward MA 9.54
# reward MA 10.16
# reward MA 9.25
# reward MA 10.42
# reward MA 9.82
# reward MA 9.74
# reward MA 10.0
# reward MA 9.6
# reward MA 9.96
# reward MA 9.95
# reward MA 9.74
# reward MA 9.98
# reward MA 10.13
# reward MA 9.54
# reward MA 9.63
# reward MA 9.91
# reward MA 10.22
# reward MA 10.18
# reward MA 10.08
# reward MA 9.92
# reward MA 9.61
# reward MA 9.96
# reward MA 10.47
# reward MA 10.23
# reward MA 9.77
# reward MA 10.08
# reward MA 9.93
# reward MA 9.4
# reward MA 9.94
# reward MA 9.57
# reward MA 10.01
# reward MA 9.57
# reward MA 10.01
# reward MA 10.12
# reward MA 10.07
# reward MA 9.73
# reward MA 9.77
# reward MA 10.49
# reward MA 10.42
# reward MA 10.39
# reward MA 9.5
# reward MA 9.46
# reward MA 9.38
# reward MA 9.59
# reward MA 10.01
# reward MA 9.45
# reward MA 10.59
# reward MA 9.72
# reward MA 10.38
# reward MA 10.04
# reward MA 9.47
# reward MA 9.64
# reward MA 9.62
# reward MA 10.32
# reward MA 9.69
# reward MA 9.47
# reward MA 9.9
# reward MA 9.72
# reward MA 9.78
# reward MA 9.75
# reward MA 10.09
# reward MA 10.35
# reward MA 9.95
# reward MA 9.65
# reward MA 9.29
# reward MA 9.57
# reward MA 9.86
# reward MA 9.48
# reward MA 10.14
# reward MA 10.13
# reward MA 9.71
# reward MA 9.86
# reward MA 10.2
# reward MA 9.61
# reward MA 10.61
# reward MA 9.9
# reward MA 9.01
# reward MA 9.76
# reward MA 9.56
# reward MA 9.89
# reward MA 10.27
# reward MA 10.45
# reward MA 10.12
# reward MA 9.35
# reward MA 9.4
# reward MA 9.63
# reward MA 10.01
# reward MA 10.05
# reward MA 9.96
# reward MA 9.93
# reward MA 9.71
# reward MA 9.75
# reward MA 9.73
# reward MA 9.97
# reward MA 10.29
# reward MA 9.93
# reward MA 10.14
# reward MA 9.5
# reward MA 10.01
# reward MA 9.86
# reward MA 10.05
# reward MA 9.43
# reward MA 9.62
# reward MA 9.8
# reward MA 9.95
# reward MA 9.99
# reward MA 10.1
# reward MA 9.71
# reward MA 10.16
# reward MA 9.5
# reward MA 9.33
# reward MA 9.62
# reward MA 10.13
# reward MA 10.12
# reward MA 10.4
# reward MA 9.75
# reward MA 9.96
# reward MA 9.32
# reward MA 9.51
# reward MA 9.89
# reward MA 9.6
# reward MA 9.77
# reward MA 10.18
# reward MA 9.5
# reward MA 9.54
# reward MA 10.28
# reward MA 9.81
# reward MA 10.1
# reward MA 10.24
# reward MA 10.14
# reward MA 10.66
# reward MA 9.5
# reward MA 10.02
# reward MA 9.99
# reward MA 9.96
# reward MA 9.43
# reward MA 10.11
# reward MA 10.19
# reward MA 9.56
# reward MA 9.86
# reward MA 9.46
# reward MA 9.52
# reward MA 9.74
# reward MA 9.88
# reward MA 9.39
# reward MA 9.93
# reward MA 10.49
# reward MA 9.78
# reward MA 9.98
# reward MA 10.3
# reward MA 10.07
# reward MA 9.55
# reward MA 9.8
# reward MA 9.58
# reward MA 10.51
# reward MA 9.34
# reward MA 9.8
# reward MA 9.63
# reward MA 9.77
# reward MA 9.82
# reward MA 9.79
# reward MA 8.99
# reward MA 9.72
# reward MA 10.15
# reward MA 10.08
# reward MA 10.2
# reward MA 10.28
# reward MA 10.26
# reward MA 10.54
# reward MA 9.8
# reward MA 9.72
# reward MA 9.64
# reward MA 9.84
# reward MA 10.12
# reward MA 10.23
# reward MA 9.48
# reward MA 9.37
# reward MA 10.14
# reward MA 10.09
# reward MA 9.76
# reward MA 9.58
# reward MA 9.83
# reward MA 10.06
# reward MA 10.24
# reward MA 10.01
# reward MA 9.29
# reward MA 9.18
# reward MA 10.16
# reward MA 10.04
# reward MA 9.27
# reward MA 9.38
# reward MA 10.01
# reward MA 9.3
# reward MA 9.73
# reward MA 9.45
# reward MA 9.75
# reward MA 10.01
# reward MA 9.78
# reward MA 9.72
# reward MA 10.63
# reward MA 10.82
# reward MA 9.41
# reward MA 10.38
# reward MA 10.68
# reward MA 9.8
# reward MA 10.48
# reward MA 9.15
# reward MA 10.32
# reward MA 9.59
# reward MA 9.71
# reward MA 9.55
# reward MA 9.84
# reward MA 10.05
# reward MA 9.1
# reward MA 9.99
# reward MA 9.4
# reward MA 9.6
# reward MA 9.38
# reward MA 9.7
# reward MA 9.16
# reward MA 9.66
# reward MA 9.32
# reward MA 9.46
# reward MA 9.58
# reward MA 10.23
# reward MA 9.93
# reward MA 10.15
# reward MA 9.52
# reward MA 9.87
# reward MA 9.87
# reward MA 10.77
# reward MA 9.55
# reward MA 9.92
# reward MA 9.6
# reward MA 9.77
# reward MA 10.14
# reward MA 10.1
# reward MA 10.01
# reward MA 9.36
# reward MA 10.03
# reward MA 9.78
# reward MA 9.58
# reward MA 9.74
# reward MA 10.37
# reward MA 9.84
# reward MA 9.12
# reward MA 9.61
# reward MA 10.45
# reward MA 9.79
# reward MA 10.11
# reward MA 10.33
# reward MA 10.02
# reward MA 9.65
# reward MA 10.34
# reward MA 9.88
# reward MA 9.74
# reward MA 9.88
# reward MA 10.13
# reward MA 9.41
# reward MA 9.6
# reward MA 9.81
# reward MA 9.89
# reward MA 9.82
# reward MA 9.67
# reward MA 9.84
# reward MA 9.57
# reward MA 9.88
# reward MA 10.32
# reward MA 10.43
# reward MA 10.61
# reward MA 10.37
# reward MA 9.66
# reward MA 9.83
# reward MA 9.8
# reward MA 9.55
# reward MA 9.5
# reward MA 9.83
# reward MA 9.61
# reward MA 9.42
# reward MA 10.36
# reward MA 10.09
# reward MA 9.39
# reward MA 9.51
# reward MA 9.56
# reward MA 10.31
# reward MA 9.81
# reward MA 10.22
# reward MA 9.53
# reward MA 9.66
# reward MA 10.13
# reward MA 9.64
# reward MA 10.04
# reward MA 10.32
# reward MA 9.68
# reward MA 9.07
# reward MA 10.03
# reward MA 9.94
# reward MA 9.75
# reward MA 10.03
# reward MA 9.99
# reward MA 9.99
# reward MA 10.51
# reward MA 9.56
# reward MA 9.82
# reward MA 9.59
# reward MA 9.8
# reward MA 10.24
# reward MA 10.04
# reward MA 9.78
# reward MA 9.58
# reward MA 9.71
# reward MA 9.67
# reward MA 9.17
# reward MA 9.33
# reward MA 10.07
# reward MA 9.44
# reward MA 9.75
# reward MA 9.73
# reward MA 10.28
# reward MA 10.05
# reward MA 10.6
# reward MA 9.82
# reward MA 8.97
# reward MA 9.59
# reward MA 9.33
# reward MA 10.3
# reward MA 9.83
# reward MA 9.99
# reward MA 9.88
# reward MA 10.29
# reward MA 10.79
# reward MA 9.37
# reward MA 9.55
# reward MA 9.94
# reward MA 9.26
# reward MA 9.7
# reward MA 9.82
# reward MA 10.24
# reward MA 9.82
# reward MA 10.15
# reward MA 9.63
# reward MA 9.78
# reward MA 10.01

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig=plt.figure(figsize=(25,10))
plt.plot(reward_MA)
